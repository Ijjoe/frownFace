# %%
import torch
model = torch.hub.load('pytorch/vision:v0.10.0', 'googlenet', pretrained=True)
model.eval()
# Out:
# Downloading: "https://github.com/pytorch/vision/zipball/v0.10.0" to C:\Users\User/.cache\torch\hub\v0.10.0.zip
# Downloading: "https://download.pytorch.org/models/googlenet-1378be20.pth" to C:\Users\User/.cache\torch\hub\checkpoints\googlenet-1378be20.pth
# 100%|██████████| 49.7M/49.7M [00:01<00:00, 45.0MB/s]
# GoogLeNet(
#   (conv1): BasicConv2d(
#     (conv): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool1): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (conv2): BasicConv2d(
#     (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): BasicConv2d(
#     (conv): Conv2d(64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
from glob import glob 
import pandas as pd
import sys
import os 
import numpy as np
from sklearn.model_selection import train_test_split

os_name = sys.platform

#경로 추출
dv = 'C:\\CIJ\\cijGit\\frownFace\\injun\\fire\\'
#리스트 csv 파일 생성으로 일관성 유지
#C:\CIJ\cijGit\frownFace\injun\fire\test\nowildfire


#내폴더 위치 확인

#폴더에서 하위 디렉토리 모두 읽어오기
# 모든 하위 디렉토리 탐색하기
file_path = glob.glob('dirs/**', recursive=True)


print(os.path.exists(dv))
base_path=''

if os_name in 'win32':
    winFolder= dv.split('\\')
    winFolder[0]=winFolder[0].replace(':',':\\')
    base_path = os.path.join(*winFolder)  #C:\CIJ\cijGit\frownFace\injun\fire
    output = os.listdir(base_path)
 
else:
    winFolder=dv.split('/')
    print('lux')
    

path = glob.glob(base_path='' + '//**', recursive=True)
print(path)


file_list = glob(os.path.join('C:\\CIJ\\cijGit\\frownFace\\injun\\fire\\test\\nowildfire\\*'))
file_list_py = [file for file in file_list if file.endswith(".jpg")]
#print(len(file_list_py))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 20
#      11 dv = 'C:\\CIJ\\cijGit\\frownFace\\injun\\fire\\'
#      12 #리스트 csv 파일 생성으로 일관성 유지
#      13 #C:\CIJ\cijGit\frownFace\injun\fire\test\nowildfire
#      14
#    (...)
#      18 #폴더에서 하위 디렉토리 모두 읽어오기
#      19 # 모든 하위 디렉토리 탐색하기
# ---> 20 file_path = glob.glob('dirs/**', recursive=True)
#      23 print(os.path.exists(dv))
#      24 base_path=''
#
# AttributeError: 'function' object has no attribute 'glob'

# %%
import numpy as np 
from glob import glob 

#경로 추출
dv = 'fire'
#리스트 csv 파일 생성으로 일관성 유지
#C:\CIJ\cijGit\frownFace\injun\fire\test\nowildfire


#내폴더 위치 확인 / 폴더에서 하위 디렉토리 모두 읽어오기
# 모든 하위 디렉토리 탐색하기
# 폴더 len 맥스값 추출
# 맥스값인 폴더만추출
def foldertoList_extraction(dv):
    ret =[]
    folderlist=[]
    listcount=[]
    file_path = glob(f'{os.getcwd()}\\{dv}\\**\\', recursive=True)
    for file in file_path:
        listcount.append(len(file.split('\\')))
        folderlist.append(file)
        
    b = np.array(listcount)   #리스트에 특정 중복값 넘파이 변환하여 
    nplist=np.where(b == max(listcount))  #지정된 인덱스만 전체 추출
    indices = nplist[0].tolist()

    for i in indices:
        ret.append(folderlist[i])
        
    return ret
# Out:
# c:\CIJ\cijGit\frownFace\injun\fire\test\nowildfire\
# c:\CIJ\cijGit\frownFace\injun\fire\test\wildfire\
# c:\CIJ\cijGit\frownFace\injun\fire\train\nowildfire\
# c:\CIJ\cijGit\frownFace\injun\fire\train\wildfire\
# c:\CIJ\cijGit\frownFace\injun\fire\valid\nowildfire\
# c:\CIJ\cijGit\frownFace\injun\fire\valid\wildfire\

# %%
from my_module import FileLocation

files='fire'

result = FileLocation().foldertoList_extraction(files)
print(result)
# Out:
# ['c:\\CIJ\\cijGit\\frownFace\\injun\\fire\\test\\nowildfire\\', 'c:\\CIJ\\cijGit\\frownFace\\injun\\fire\\test\\wildfire\\', 'c:\\CIJ\\cijGit\\frownFace\\injun\\fire\\train\\nowildfire\\', 'c:\\CIJ\\cijGit\\frownFace\\injun\\fire\\train\\wildfire\\', 'c:\\CIJ\\cijGit\\frownFace\\injun\\fire\\valid\\nowildfire\\', 'c:\\CIJ\\cijGit\\frownFace\\injun\\fire\\valid\\wildfire\\']
